# %% [markdown]
# # Designing a Recommender System to alleivate mental health problems by studying different music genres

# %% [markdown]
# The purpose of the notebook is to study different user attributes like age , type of mental health challenges like anxiety, depression, insomnia or OCD that the user is undergoing and recommend the suitable music genre based on its likeability. The notebook has been taken from https://github.com/tanyakuznetsova/Music_Mental_Health/blob/main/Rec_system_Music_Mental_Health.ipynb

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/mental-health-codes"
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/mental-health-codes')

# %reload_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/mental-health-codes

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, classification_report
from sklearn import preprocessing

# %%
data = pd.read_csv('mxmh_survey_results.csv')

# %%
data.shape
# Out:
# (736, 33)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
data["Music effects"].unique() #labels
# Out:
# array([nan, 'No effect', 'Improve', 'Worsen'], dtype=object)

# %%
data.isnull().values.any()
# Out:
# True

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Drop NULL or replace?
# *   Looks like dropping nulls will suffice. Compared to the amount of data entries, dropping shouldn't be a concern here [except BPM]
#
# Dropping columns?
#
# *   BPM is not a column we are intending to use, so we can drop. (it also has the most nulls)
# * Perhaps drop Timestamp as well? Not sure how necessary it is for us.

# %%
#See nulls across the dataset
data.isna().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# Depression                        0
# Insomnia                          0
# OCD                               0
# Music effects                     8
# Permissions                       0
# dtype: int64

# %%
#Drop nulls
clean_data = data.dropna()

# %%
len(clean_data)
# Out:
# 616

# %%
#verify nulls are gone
clean_data.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Primary streaming service       0
# Hours per day                   0
# While working                   0
# Instrumentalist                 0
# Composer                        0
# Fav genre                       0
# Exploratory                     0
# Foreign languages               0
# BPM                             0
# Frequency [Classical]           0
# Frequency [Country]             0
# Frequency [EDM]                 0
# Frequency [Folk]                0
# Frequency [Gospel]              0
# Frequency [Hip hop]             0
# Frequency [Jazz]                0
# Frequency [K pop]               0
# Frequency [Latin]               0
# Frequency [Lofi]                0
# Frequency [Metal]               0
# Frequency [Pop]                 0
# Frequency [R&B]                 0
# Frequency [Rap]                 0
# Frequency [Rock]                0
# Frequency [Video game music]    0
# Anxiety                         0
# Depression                      0
# Insomnia                        0
# OCD                             0
# Music effects                   0
# Permissions                     0
# dtype: int64

# %%
#drop unneccsary columns
clean_data = clean_data.drop(columns=['Timestamp', 'Composer','BPM','Permissions'])

# %%
#verify columns are dropped
clean_data.head(2)
# Out:
#     Age Primary streaming service  Hours per day While working  \
# 2  18.0                   Spotify            4.0            No
# 3  61.0             YouTube Music            2.5           Yes
#
#   Instrumentalist         Fav genre Exploratory Foreign languages  \
# 2              No  Video game music          No               Yes
# 3              No              Jazz         Yes               Yes
#
#   Frequency [Classical] Frequency [Country]  ... Frequency [Pop]  \
# 2                 Never               Never  ...          Rarely
# 3             Sometimes               Never  ...       Sometimes
#
#   Frequency [R&B] Frequency [Rap] Frequency [Rock]  \
# 2           Never          Rarely           Rarely
# 3       Sometimes           Never            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
#
# [2 rows x 29 columns]

# %%
data.Permissions.unique() #can be dropped, everyone agreed
# Out:
# array(['I understand.'], dtype=object)

# %% [markdown]
# #Mental Health Conditions
# When it comes to the mental health conditions this study is concerned with, ate there observable trends? Do any of these conditions co-occur, is there any correlation? For example, do any of the four mental health conditions - anxiety, depression, insomnia and OCD - go together more often that other combinations?

# %%
mh_data = data[['Anxiety', 'Depression', 'Insomnia', 'OCD']]

import seaborn as sns

plt.figure(figsize=(10,8))
plt.title('Mental Health Conditions Correlation Heatmap')
sns.heatmap(mh_data.corr(), cmap = 'crest', annot=True, fmt=".4f",  linewidths=0.5)
plt.show()

# %% [markdown]
# It appears that the most common and prominent co-occurring pair is *anxiety and depression*.
# It is followed by *insomnia and depression* as the second highest correlated pair; the third is *anxiety and OCD*, although the correlation is not as clear and significant in these cases.

# %% [markdown]
# What is the spread of the severity of the conditions? They are rated on the
# scale from 0 to 10. Let's compare them side by side:

# %%
fig, ax = plt.subplots(figsize = (10, 8))

ax.boxplot(mh_data, patch_artist = True,
           notch = True,
           labels = mh_data.columns,
           showfliers = True,
           )

ax.set(
    title='Comparison of the mental health conditions',
    #xticklabels = mh_data.columns,
    ylabel='Severity score',
)
plt.show()

# %%
mh_data.plot.hist(cmap = 'tab20c',
                  edgecolor = 'white',
                  figsize = (10, 8),
                  subplots = True, #comment out to compare with the previous version
                  title = 'Comparison of the mental health conditions ')

plt.xlabel('Severity Score')
#plt.ylabel('Counts')

plt.show()

# %% [markdown]
# # Encoding input data before passing to Collaborative Filtering module

# %%
# Encode our categorical variables into numeric values

encoded_data = pd.DataFrame()

encoder = preprocessing.LabelEncoder()

for column in clean_data.select_dtypes(include='object'):
    encoded_data[column] = encoder.fit_transform(clean_data[column])

encoded_data.head()
# Out:
#    Primary streaming service  While working  Instrumentalist  Fav genre  \
# 0                          4              0                0         15
# 1                          5              1                0          6
# 2                          4              1                0         12
# 3                          4              1                1          6
# 4                          5              1                1         15
#
#    Exploratory  Foreign languages  Frequency [Classical]  Frequency [Country]  \
# 0            0                  1                      0                    0
# 1            1                  1                      2                    0
# 2            1                  0                      0                    0
# 3            1                  1                      1                    2
# 4            1                  1                      2                    0
#
#    Frequency [EDM]  Frequency [Folk]  ...  Frequency [K pop]  \
# 0                3                 0  ...                  3
# 1                0                 1  ...                  2
# 2                1                 0  ...                  3
# 3                0                 0  ...                  3
# 4                1                 2  ...                  0
#
#    Frequency [Latin]  Frequency [Lofi]  Frequency [Metal]  Frequency [Pop]  \
# 0                  0                 2                  2                1
# 1                  3                 2                  0                2
# 2                  2                 2                  0                2
# 3                  1                 3                  1                3
# 4                  1                 1                  1                1
#
#    Frequency [R&B]  Frequency [Rap]  Frequency [Rock]  \
# 0                0                1                 1
# 1                2                0                 0
# 2                3                3                 0
# 3                3                3                 3
# 4                1                0                 0
#
#    Frequency [Video game music]  Music effects
# 0                             3              1
# 1                             0              0
# 2                             1              0
# 3                             0              0
# 4                             2              0
#
# [5 rows x 23 columns]

# %%
clean_data.head()
# Out:
#     Age Primary streaming service  Hours per day While working  \
# 2  18.0                   Spotify            4.0            No
# 3  61.0             YouTube Music            2.5           Yes
# 4  18.0                   Spotify            4.0           Yes
# 5  18.0                   Spotify            5.0           Yes
# 6  18.0             YouTube Music            3.0           Yes
#
#   Instrumentalist         Fav genre Exploratory Foreign languages  \
# 2              No  Video game music          No               Yes
# 3              No              Jazz         Yes               Yes
# 4              No               R&B         Yes                No
# 5             Yes              Jazz         Yes               Yes
# 6             Yes  Video game music         Yes               Yes
#
#   Frequency [Classical] Frequency [Country]  ...  Frequency [Pop]  \
# 2                 Never               Never  ...           Rarely
# 3             Sometimes               Never  ...        Sometimes
# 4                 Never               Never  ...        Sometimes
# 5                Rarely           Sometimes  ...  Very frequently
# 6             Sometimes               Never  ...           Rarely
#
#    Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 2            Never           Rarely           Rarely
# 3        Sometimes            Never            Never
# 4  Very frequently  Very frequently            Never
# 5  Very frequently  Very frequently  Very frequently
# 6           Rarely            Never            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
# 5                        Never     8.0        8.0      7.0  7.0       Improve
# 6                    Sometimes     4.0        8.0      6.0  0.0       Improve
#
# [5 rows x 29 columns]

# %%
print(f'Validate both datasets are consistent post encoder. \nClean dataset: {len(clean_data)} \nEncoded Dataset: {len(encoded_data)}')
# Out:
# Validate both datasets are consistent post encoder.
# Clean dataset: 616
# Encoded Dataset: 616

# %%
#looks at max value of each column (i.e. 0-15) to make sure all categorical variables have been accounted for to their numerical counterpart
encoded_data.max(axis=0)
# Out:
# Primary streaming service        5
# While working                    1
# Instrumentalist                  1
# Fav genre                       15
# Exploratory                      1
# Foreign languages                1
# Frequency [Classical]            3
# Frequency [Country]              3
# Frequency [EDM]                  3
# Frequency [Folk]                 3
# Frequency [Gospel]               3
# Frequency [Hip hop]              3
# Frequency [Jazz]                 3
# Frequency [K pop]                3
# Frequency [Latin]                3
# Frequency [Lofi]                 3
# Frequency [Metal]                3
# Frequency [Pop]                  3
# Frequency [R&B]                  3
# Frequency [Rap]                  3
# Frequency [Rock]                 3
# Frequency [Video game music]     3
# Music effects                    2
# dtype: int64

# %% [markdown]
# Docs For Recomender System Reference:
# * YT Video: https://www.youtube.com/watch?v=G4MBc40rQ2k
# * Geeksforgeeks(high level w/ implementation): https://www.geeksforgeeks.org/recommendation-system-in-python/
# * Movie rec system: https://thecleverprogrammer.com/2020/05/20/data-science-project-movie-recommendation-system/
# * high lvl implementation: https://365datascience.com/tutorials/how-to-build-recommendation-system-in-python/

# %% [markdown]
# # Collaborative Filtering Recommender Systems

# %% [markdown]
# *The following goal of the collaborative filtering recommender system is to predict a positive outcome (an improvement) in mental health.*

# %% [markdown]
# To accomplish this, we engineer 'implicit' ratings from listeners based on how often they listen to a particular genre. (e.g. listening to Classical music 'Very Freqeuntly' is given a high rating (3) and listening to Hip Hop music 'Never' is given a rating of 0

# %% [markdown]
# *recommended path forward:*
# 1. Create a sub df with all entries that have a positive music effect.
# 2. Drop everything excep frequencies.
# 3. Implement a Rec System

# %%
# 3. Implement a Rec System
# %pip install scikit-surprise -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for scikit-surprise (pyproject.toml) ... done

# %%
encoded_data.head(2)
# Out:
#    Primary streaming service  While working  Instrumentalist  Fav genre  \
# 0                          4              0                0         15
# 1                          5              1                0          6
#
#    Exploratory  Foreign languages  Frequency [Classical]  Frequency [Country]  \
# 0            0                  1                      0                    0
# 1            1                  1                      2                    0
#
#    Frequency [EDM]  Frequency [Folk]  ...  Frequency [K pop]  \
# 0                3                 0  ...                  3
# 1                0                 1  ...                  2
#
#    Frequency [Latin]  Frequency [Lofi]  Frequency [Metal]  Frequency [Pop]  \
# 0                  0                 2                  2                1
# 1                  3                 2                  0                2
#
#    Frequency [R&B]  Frequency [Rap]  Frequency [Rock]  \
# 0                0                1                 1
# 1                2                0                 0
#
#    Frequency [Video game music]  Music effects
# 0                             3              1
# 1                             0              0
#
# [2 rows x 23 columns]

# %%
#1. Create a sub df with all entries that have a positive music effect.
improved_df = encoded_data[encoded_data['Music effects'] == 1]

# %%
#validate 1
improved_df[improved_df['Music effects'] != 1]
# Out:
# Empty DataFrame
# Columns: [Primary streaming service, While working, Instrumentalist, Fav genre, Exploratory, Foreign languages, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Music effects]
# Index: []
#
# [0 rows x 23 columns]

# %%
# create list of tuples[(uid, iid, rate)]
def vectorize(user_id, row):
  new_row = row.drop(labels=['Primary streaming service', 'While working','Instrumentalist','Fav genre','Exploratory','Foreign languages','Music effects'], axis=0)
  ratings = []
  for music,rating in new_row.items():
    ratings.append((user_id, music, rating))

  return ratings

# %%
user_ratings = []

for user, row in improved_df.iterrows():
  user_ratings += vectorize(user, row)

# %%
#list --> df for rec system input
user_ratings_df = pd.DataFrame(user_ratings)

# %%
user_ratings_df.head(20)
# Out:
#      0                             1  2
# 0    0         Frequency [Classical]  0
# 1    0           Frequency [Country]  0
# 2    0               Frequency [EDM]  3
# 3    0              Frequency [Folk]  0
# 4    0            Frequency [Gospel]  0
# 5    0           Frequency [Hip hop]  1
# 6    0              Frequency [Jazz]  1
# 7    0             Frequency [K pop]  3
# 8    0             Frequency [Latin]  0
# 9    0              Frequency [Lofi]  2
# 10   0             Frequency [Metal]  2
# 11   0               Frequency [Pop]  1
# 12   0               Frequency [R&B]  0
# 13   0               Frequency [Rap]  1
# 14   0              Frequency [Rock]  1
# 15   0  Frequency [Video game music]  3
# 16  18         Frequency [Classical]  1
# 17  18           Frequency [Country]  1
# 18  18               Frequency [EDM]  2
# 19  18              Frequency [Folk]  0

# %%
#Performance Check Pt1 of Rec System
from surprise import Dataset, Reader, SVD, KNNBasic
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise import accuracy
import random
from surprise.model_selection import GridSearchCV


#Load Dataset
reader = Reader(rating_scale=(0, 3))
data = Dataset.load_from_df(user_ratings_df,reader)
raw_ratings = data.raw_ratings

# shuffle ratings if you want
random.shuffle(raw_ratings)

# 90% trainset, 10% testset
threshold = int(.9 * len(raw_ratings))
trainset_raw_ratings = raw_ratings[:threshold]
test_raw_ratings = raw_ratings[threshold:]

data.raw_ratings = trainset_raw_ratings  # data is now your trainset
#data.split(n_folds=3)

#trainset = data.build_full_trainset()
# trainset = data.construct_trainset()
# testset = data.construct_testset()

# Select & Train Model
sim_options = {
     "name": "pearson",
}
model = KNNBasic(sim_options=sim_options)
# retrain on the whole train set
trainset = data.build_full_trainset()
model.fit(trainset)
cross_validate(model, data, measures=["RMSE", "MAE"], cv=5, verbose=True)

# now test on the trainset
testset = data.construct_testset(trainset_raw_ratings)
predictions = model.test(testset)
print('Accuracy on the trainset:')
accuracy.rmse(predictions)
accuracy.mae(predictions)
accuracy.mse(predictions)
accuracy.fcp(predictions)

# now test on the testset
testset = data.construct_testset(test_raw_ratings)
predictions = model.test(testset)
print('Accuracy on the testset:')
accuracy.rmse(predictions)
accuracy.mae(predictions)
accuracy.mse(predictions)
accuracy.fcp(predictions)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9656  1.0089  0.9802  0.9272  0.9299  0.9624  0.0309
# MAE (testset)     0.7957  0.8477  0.8018  0.7701  0.7732  0.7977  0.0279
# Fit time          0.00    0.01    0.00    0.00    0.01    0.00    0.00
# Test time         0.04    0.04    0.04    0.05    0.06    0.05    0.01
# Accuracy on the trainset:
# RMSE: 0.7404
# MAE:  0.6013
# MSE: 0.5482
# FCP:  0.8843
# Accuracy on the testset:
# RMSE: 0.9318
# MAE:  0.7880
# MSE: 0.8683
# FCP:  0.5256
# 0.5256327060350422

# %%
#Predictions - re-train on unseen user
from surprise.accuracy import rmse
sad_df = encoded_data[encoded_data['Music effects'] == 0]

all_items = user_ratings_df[1].unique()
print(all_items)

predictions=[]

for user_id, row in sad_df.iterrows():
  sad_boi_raw = vectorize(user_id, row)
  user_included_df = pd.DataFrame(user_ratings + sad_boi_raw)

  data = Dataset.load_from_df(user_included_df,reader)
  trainset = data.build_full_trainset()
  model.fit(trainset)

  # Predict ratings for unrated items
  for iid in all_items:
    pred = model.predict(user_id, iid )
    print(pred)
    predictions.append([user_id, iid, pred.est])
# Out:
# Streaming output truncated to the last 5000 lines.
# user: 248        item: Frequency [EDM] r_ui = None   est = 0.54   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Folk] r_ui = None   est = 1.61   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Gospel] r_ui = None   est = 0.28   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Hip hop] r_ui = None   est = 1.26   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Jazz] r_ui = None   est = 1.20   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [K pop] r_ui = None   est = 0.21   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Latin] r_ui = None   est = 0.94   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Lofi] r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Metal] r_ui = None   est = 1.08   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Pop] r_ui = None   est = 1.98   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [R&B] r_ui = None   est = 1.54   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Rap] r_ui = None   est = 1.22   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Rock] r_ui = None   est = 2.59   {'actual_k': 40, 'was_impossible': False}
# user: 248        item: Frequency [Video game music] r_ui = None   est = 0.30   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 249        item: Frequency [Classical] r_ui = None   est = 1.03   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Country] r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [EDM] r_ui = None   est = 0.89   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Folk] r_ui = None   est = 0.73   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Gospel] r_ui = None   est = 0.13   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Hip hop] r_ui = None   est = 2.25   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Jazz] r_ui = None   est = 1.02   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [K pop] r_ui = None   est = 0.38   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Latin] r_ui = None   est = 0.48   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Lofi] r_ui = None   est = 1.28   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Metal] r_ui = None   est = 1.07   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Pop] r_ui = None   est = 2.39   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [R&B] r_ui = None   est = 2.00   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Rap] r_ui = None   est = 2.14   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Rock] r_ui = None   est = 2.32   {'actual_k': 40, 'was_impossible': False}
# user: 249        item: Frequency [Video game music] r_ui = None   est = 0.94   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 250        item: Frequency [Classical] r_ui = None   est = 1.02   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Country] r_ui = None   est = 0.42   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [EDM] r_ui = None   est = 1.19   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Folk] r_ui = None   est = 0.55   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Gospel] r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Hip hop] r_ui = None   est = 2.08   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Jazz] r_ui = None   est = 1.14   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [K pop] r_ui = None   est = 0.24   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [Latin] r_ui = None   est = 0.18   {'actual_k': 40, 'was_impossible': False}
# user: 250        item: Frequency [
{'actual_k': 40, 'was_impossible': False}
# user: 256        item: Frequency [Rap] r_ui = None   est = 2.06   {'actual_k': 40, 'was_impossible': False}
# user: 256        item: Frequency [Rock] r_ui = None   est = 1.52   {'actual_k': 40, 'was_impossible': False}
# user: 256        item: Frequency [Video game music] r_ui = None   est = 1.27   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 258        item: Frequency [Classical] r_ui = None   est = 0.85   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Country] r_ui = None   est = 0.64   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [EDM] r_ui = None   est = 1.72   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Folk] r_ui = None   est = 1.04   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Gospel] r_ui = None   est = 0.05   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Hip hop] r_ui = None   est = 1.58   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Jazz] r_ui = None   est = 0.90   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [K pop] r_ui = None   est = 0.45   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Latin] r_ui = None   est = 0.13   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Lofi] r_ui = None   est = 0.98   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Metal] r_ui = None   est = 1.95   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Pop] r_ui = None   est = 1.70   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [R&B] r_ui = None   est = 1.09   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Rap] r_ui = None   est = 1.87   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Rock] r_ui = None   est = 2.01   {'actual_k': 40, 'was_impossible': False}
# user: 258        item: Frequency [Video game music] r_ui = None   est = 1.95   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 259        item: Frequency [Classical] r_ui = None   est = 0.82   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Country] r_ui = None   est = 0.71   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [EDM] r_ui = None   est = 1.31   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Folk] r_ui = None   est = 0.96   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Gospel] r_ui = None   est = 0.13   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Hip hop] r_ui = None   est = 2.06   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Jazz] r_ui = None   est = 0.74   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [K pop] r_ui = None   est = 0.35   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Latin] r_ui = None   est = 0.41   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Lofi] r_ui = None   est = 1.23   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Metal] r_ui = None   est = 1.25   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Pop] r_ui = None   est = 2.28   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [R&B] r_ui = None   est = 1.76   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Rap] r_ui = None   est = 1.96   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Rock] r_ui = None   est = 2.30   {'actual_k': 40, 'was_impossible': False}
# user: 259        item: Frequency [Video game music] r_ui = None   est = 0.84   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 261        item: Frequency [Classical] r_ui = None   est = 0.85   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Country] r_ui = None   est = 1.42   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [EDM] r_ui = None   est = 0.47   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Folk] r_ui = None   est = 1.33   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Gospel] r_ui = None   est = 0.31   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Hip hop] r_ui = None   est = 1.34   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Jazz] r_ui = None   est = 0.75   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [K pop] r_ui = None   est = 0.14   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Latin] r_ui = None   est = 0.30   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Lofi] r_ui = None   est = 0.51   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Metal] r_ui = None   est = 2.07   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Pop] r_ui = None   est = 1.41   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [R&B] r_ui = None   est = 0.74   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Rap] r_ui = None   est = 1.52   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Rock] r_ui = None   est = 2.66   {'actual_k': 40, 'was_impossible': False}
# user: 261        item: Frequency [Video game music] r_ui = None   est = 0.93   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 262        item: Frequency [Classical] r_ui = None   est = 0.70   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Country] r_ui = None   est = 0.61   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [EDM] r_ui = None   est = 0.86   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Folk] r_ui = None   est = 1.04   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Gospel] r_ui = None   est = 0.19   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Hip hop] r_ui = None   est = 1.02   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Jazz] r_ui = None   est = 0.81   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [K pop] r_ui = None   est = 0.46   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Latin] r_ui = None   est = 0.33   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Lofi] r_ui = None   est = 0.61   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Metal] r_ui = None   est = 2.30   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Pop] r_ui = None   est = 2.03   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [R&B] r_ui = None   est = 1.15   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Rap] r_ui = None   est = 1.39   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Rock] r_ui = None   est = 2.67   {'actual_k': 40, 'was_impossible': False}
# user: 262        item: Frequency [Video game music] r_ui = None   est = 1.38   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 263        item: Frequency [Classical] r_ui = None   est = 1.28   {'actual_k': 40, 'was_impossible': False}
# user: 263        item: Frequency [
{'actual_k': 40, 'was_impossible': False}
# user: 279        item: Frequency [Rock] r_ui = None   est = 2.57   {'actual_k': 40, 'was_impossible': False}
# user: 279        item: Frequency [Video game music] r_ui = None   est = 1.18   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 281        item: Frequency [Classical] r_ui = None   est = 0.88   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Country] r_ui = None   est = 1.65   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [EDM] r_ui = None   est = 0.76   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Folk] r_ui = None   est = 1.51   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Gospel] r_ui = None   est = 0.36   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Hip hop] r_ui = None   est = 1.53   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Jazz] r_ui = None   est = 0.67   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [K pop] r_ui = None   est = 0.30   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Latin] r_ui = None   est = 0.37   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Lofi] r_ui = None   est = 0.53   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Metal] r_ui = None   est = 1.35   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Pop] r_ui = None   est = 2.17   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [R&B] r_ui = None   est = 1.12   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Rap] r_ui = None   est = 1.55   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Rock] r_ui = None   est = 2.50   {'actual_k': 40, 'was_impossible': False}
# user: 281        item: Frequency [Video game music] r_ui = None   est = 0.58   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 285        item: Frequency [Classical] r_ui = None   est = 1.18   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Country] r_ui = None   est = 0.60   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [EDM] r_ui = None   est = 0.83   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Folk] r_ui = None   est = 0.83   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Gospel] r_ui = None   est = 0.14   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Hip hop] r_ui = None   est = 2.20   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Jazz] r_ui = None   est = 1.32   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [K pop] r_ui = None   est = 0.39   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Latin] r_ui = None   est = 0.46   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Lofi] r_ui = None   est = 1.37   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Metal] r_ui = None   est = 1.03   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Pop] r_ui = None   est = 2.38   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [R&B] r_ui = None   est = 1.47   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Rap] r_ui = None   est = 2.04   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Rock] r_ui = None   est = 2.43   {'actual_k': 40, 'was_impossible': False}
# user: 285        item: Frequency [Video game music] r_ui = None   est = 0.95   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 286        item: Frequency [Classical] r_ui = None   est = 0.99   {'actual_k': 40, 'was_impossible': False}
# ...
# user: 606        item: Frequency [Hip hop] r_ui = None   est = 1.76   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Jazz] r_ui = None   est = 1.14   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [K pop] r_ui = None   est = 0.21   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Latin] r_ui = None   est = 0.19   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Lofi] r_ui = None   est = 1.15   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Metal] r_ui = None   est = 1.52   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Pop] r_ui = None   est = 1.66   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [R&B] r_ui = None   est = 1.18   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Rap] r_ui = None   est = 1.71   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Rock] r_ui = None   est = 2.02   {'actual_k': 40, 'was_impossible': False}
# user: 606        item: Frequency [Video game music] r_ui = None   est = 1.76   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 608        item: Frequency [Classical] r_ui = None   est = 0.93   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [Country] r_ui = None   est = 1.50   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [EDM] r_ui = None   est = 0.68   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [Folk] r_ui = None   est = 1.25   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [Gospel] r_ui = None   est = 0.51   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [Hip hop] r_ui = None   est = 1.31   {'actual_k': 40, 'was_impossible': False}
# user: 608        item: Frequency [
{'actual_k': 40, 'was_impossible': False}
# user: 612        item: Frequency [R&B] r_ui = None   est = 0.69   {'actual_k': 40, 'was_impossible': False}
# user: 612        item: Frequency [Rap] r_ui = None   est = 0.76   {'actual_k': 40, 'was_impossible': False}
# user: 612        item: Frequency [Rock] r_ui = None   est = 2.30   {'actual_k': 40, 'was_impossible': False}
# user: 612        item: Frequency [Video game music] r_ui = None   est = 1.67   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 613        item: Frequency [Classical] r_ui = None   est = 1.08   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Country] r_ui = None   est = 0.69   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [EDM] r_ui = None   est = 1.52   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Folk] r_ui = None   est = 0.73   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Gospel] r_ui = None   est = 0.21   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Hip hop] r_ui = None   est = 2.42   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Jazz] r_ui = None   est = 0.85   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [K pop] r_ui = None   est = 0.47   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Latin] r_ui = None   est = 0.60   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Lofi] r_ui = None   est = 1.26   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Metal] r_ui = None   est = 0.71   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Pop] r_ui = None   est = 2.30   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [R&B] r_ui = None   est = 1.88   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Rap] r_ui = None   est = 2.06   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Rock] r_ui = None   est = 1.60   {'actual_k': 40, 'was_impossible': False}
# user: 613        item: Frequency [Video game music] r_ui = None   est = 1.01   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 614        item: Frequency [Classical] r_ui = None   est = 2.46   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Country] r_ui = None   est = 0.56   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [EDM] r_ui = None   est = 0.68   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Folk] r_ui = None   est = 0.92   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Gospel] r_ui = None   est = 0.18   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Hip hop] r_ui = None   est = 0.66   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Jazz] r_ui = None   est = 1.29   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [K pop] r_ui = None   est = 0.32   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Latin] r_ui = None   est = 0.28   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Lofi] r_ui = None   est = 0.84   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Metal] r_ui = None   est = 0.94   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Pop] r_ui = None   est = 1.46   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [R&B] r_ui = None   est = 0.58   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Rap] r_ui = None   est = 0.63   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Rock] r_ui = None   est = 1.44   {'actual_k': 40, 'was_impossible': False}
# user: 614        item: Frequency [Video game music] r_ui = None   est = 1.75   {'actual_k': 40, 'was_impossible': False}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 615        item: Frequency [Classical] r_ui = None   est = 1.45   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Country] r_ui = None   est = 0.64   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [EDM] r_ui = None   est = 1.49   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Folk] r_ui = None   est = 1.10   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Gospel] r_ui = None   est = 0.22   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Hip hop] r_ui = None   est = 2.39   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Jazz] r_ui = None   est = 1.55   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [K pop] r_ui = None   est = 0.89   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Latin] r_ui = None   est = 0.57   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Lofi] r_ui = None   est = 0.92   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Metal] r_ui = None   est = 0.65   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Pop] r_ui = None   est = 2.19   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [R&B] r_ui = None   est = 1.78   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Rap] r_ui = None   est = 2.21   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Rock] r_ui = None   est = 2.22   {'actual_k': 40, 'was_impossible': False}
# user: 615        item: Frequency [Video game music] r_ui = None   est = 1.01   {'actual_k': 40, 'was_impossible': False}

# %%
recommender_output_dataframe = pd.DataFrame(predictions, columns=["user_id","genre", "score"])
recommender_output_dataframe.head()
# Out:
#    user_id                  genre     score
# 0        1  Frequency [Classical]  2.161321
# 1        1    Frequency [Country]  0.350627
# 2        1        Frequency [EDM]  0.618204
# 3        1       Frequency [Folk]  0.872143
# 4        1     Frequency [Gospel]  0.685762

# %% [markdown]
# ##Finding Top Recommended items based on rating Scores

# %%
idx = recommender_output_dataframe.groupby(['user_id'])['score'].idxmax()
result = recommender_output_dataframe.loc[idx, ['user_id', 'genre', 'score']]
result
# Out:
#       user_id                  genre     score
# 11          1        Frequency [Pop]  2.335593
# 27          2        Frequency [Pop]  2.371774
# 43          3        Frequency [Pop]  2.389513
# 48          4  Frequency [Classical]  2.146259
# 75          5        Frequency [Pop]  2.367614
# ...       ...                    ...       ...
# 7374      611       Frequency [Rock]  2.629657
# 7387      612        Frequency [Pop]  2.523934
# 7397      613    Frequency [Hip hop]  2.423108
# 7408      614  Frequency [Classical]  2.464174
# 7429      615    Frequency [Hip hop]  2.389278
#
# [465 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# bar chart
plt.figure(figsize=(10, 8))
pastel_palette = sns.color_palette("pastel", n_colors=len(result['user_id'].unique()))

plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)

plt.title('Top Recommended Genre for Each User')
plt.xlabel('Genre')
plt.ylabel('Number of Users', fontsize=12)

plt.xticks(rotation=45, ha='right', fontsize = 12)
plt.yticks(fontsize = 12)



for p in plot.patches:
    plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=10, color='black')


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-33-ac4fe551e4ae>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)
# <ipython-input-33-ac4fe551e4ae>:8: UserWarning: The palette list has more values (465) than needed (12), which may not be intended.
#   plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)

# %% [markdown]
# ##Finding Bottom Recommended items based on rating Scores

# %%
idx = recommender_output_dataframe.groupby(['user_id'])['score'].idxmin()
result = recommender_output_dataframe.loc[idx, ['user_id', 'genre', 'score']]
result
# Out:
#       user_id                genre     score
# 10          1    Frequency [Metal]  0.278114
# 17          2  Frequency [Country]  0.248601
# 36          3   Frequency [Gospel]  0.161244
# 55          4    Frequency [K pop]  0.178321
# 68          5   Frequency [Gospel]  0.217986
# ...       ...                  ...       ...
# 7364      611   Frequency [Gospel]  0.201647
# 7380      612   Frequency [Gospel]  0.196503
# 7396      613   Frequency [Gospel]  0.213956
# 7412      614   Frequency [Gospel]  0.176830
# 7428      615   Frequency [Gospel]  0.221338
#
# [465 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# bar chart
plt.figure(figsize=(10, 8))
pastel_palette = sns.color_palette("pastel", n_colors=len(result['user_id'].unique()))

plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)

plt.title('Bottom Recommended Genre for Each User')
plt.xlabel('Genre')
plt.ylabel('Number of Users', fontsize=12)

plt.xticks(rotation=45, ha='right', fontsize = 12)
plt.yticks(fontsize = 12)



for p in plot.patches:
    plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=10, color='black')


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-e4aedaca9058>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)
# <ipython-input-35-e4aedaca9058>:8: UserWarning: The palette list has more values (465) than needed (9), which may not be intended.
#   plot = sns.countplot(data=result, x='genre', palette=pastel_palette, order=result['genre'].value_counts().index)
